# %% [markdown]
# #### BASIC PLOTTING

# %%
library(repr)

options("repr.plot.width"= 6,"repr.plot.height"= 6)
foo <- c(1.1,2,3.5,3.9,4.2)
bar <- c(2,2.2,-1.3,0,0.2)
plot(foo,bar)
# Out:
# plot without title

# %%
baz <- cbind(foo,bar)
print(baz)
# Out:
#      foo  bar
# [1,] 1.1  2.0
# [2,] 2.0  2.2
# [3,] 3.5 -1.3
# [4,] 3.9  0.0
# [5,] 4.2  0.2

# %%
plot(baz)
# Out:
# plot without title

# %% [markdown]
# #### Graphical Parameters

# %% [markdown]
# - type: Tells R how to plot the supplied coordinates
# - main, xlab, ylab: Options to include plot title, the horizontal axis label,and the vertical axis label, respectively.
# - col: Color (or colors) to use for plotting points and lines.
# - pch: Stands for point character. This selects which character to use for plotting individual points.
# - cex: Stands for character expansion. This controls the size of plotted point characters.
# - lty: Stands for line type. This specifies the type of line (such as solid, dotted, or dashed).
# - lwd: Stands for line width. This controls the thickness of plotted lines.
# - xlim, ylim: Provides limits for the horizontal range and vertical range (respectively) of the plotting region.

# %%
plot(foo,bar,type="l") #line, default value for type is "p" (points)
# Out:
# plot without title

# %%
plot(foo,bar,type="b") #both
# Out:
# plot without title

# %%
#axis labels and titles
plot(foo,bar,type="b",main="My lovely plot",xlab="x axis label",ylab="location y")
plot(foo,bar,type="b",main="My lovely plot\ntitle on two lines",xlab="",ylab="")
# Out:
# Plot with title “My lovely plot”
# Plot with title “My lovely plot
# title on two lines”

# %%
#Adding color
plot(foo,bar,type="b",main="My lovely plot",xlab="",ylab="",col=2)
plot(foo,bar,type="b",main="My lovely plot",xlab="",ylab="",col="seagreen4")
# Out:
# Plot with title "My lovely plot"
# Plot with title "My lovely plot"

# %%
plot(foo,bar,type="b",main="My lovely plot",xlab="",ylab="",col=4,pch=8,lty=2,cex=2.3,lwd=3.3)
plot(foo,bar,type="b",main="My lovely plot",xlab="",ylab="",col=6,pch=15,lty=3,cex=0.7,lwd=2)
# Out:
# Plot with title “My lovely plot”
# Plot with title “My lovely plot”

# %%
plot(foo,bar,type="b",main="My lovely plot",xlab="",ylab="",col=4,pch=8,lty=2,cex=2.3,lwd=3.3,xlim=c(-10,5),ylim=c(-3,3))
plot(foo,bar,type="b",main="My lovely plot",xlab="",ylab="",col=6,pch=15,lty=3,cex=0.7,lwd=2,xlim=c(3,5),ylim=c(-0.5,0.2))
# Out:
# Plot with title “My lovely plot”
# Plot with title “My lovely plot”

# %% [markdown]
# ![image.png](attachment:19267297-f7bd-4923-a942-cf7332905f7e.png)

# %% [markdown]
# #### Adding Points, Lines, and Text to an Existing Plot

# %% [markdown]
# - points: Adds points
# - lines, abline, segments: Adds lines
# - text: Writes text
# - arrows: Adds arrows
# - legend: Adds a legend

# %%
x <- 1:20
y <- c(-1.49,3.37,2.59,-2.78,-3.94,-0.92,6.43,8.51,3.41,-8.23,
-12.01,-6.58,2.87,14.12,9.63,-4.58,-14.78,-11.67,1.17,15.62)

# %%
options(repr.plot.width=12, repr.plot.height=12)

# %%
plot(x,y,type="n",main="") #type="n" creats an empty plot
abline(h=c(-5,5),col="red",lty=2,lwd=2) # add straight lines
# Out:
# Plot with title “”

# %%
plot(x,y,type="n",main="") #type="n" creats an empty plot
abline(h=c(-5,5),col="red",lty=2,lwd=2) # add straight lines
# “from” coordinate (given as x0 and y0) and a “to” coordinate (as x1 and y1)
segments(x0=c(5,15),y0=c(-5,-5),x1=c(5,15),y1=c(5,5),col=5,lty=3,lwd=2)
# Out:
# Plot with title “”

# %%
plot(x,y,type="n",main="") #type="n" creats an empty plot
abline(h=c(-5,5),col="red",lty=2,lwd=2) # add straight lines
# “from” coordinate (given as x0 and y0) and a “to” coordinate (as x1 and y1)
segments(x0=c(5,15),y0=c(-5,-5),x1=c(5,15),y1=c(5,5),col="red",lty=3,lwd=2) 
points(x[y>=5],y[y>=5],pch=4,col="darkmagenta",cex=2)
points(x[y<=-5],y[y<=-5],pch=4,col="darkgreen",cex=2)
points(x[(x>=5&x<=15)&(y>-5&y<5)],y[(x>=5&x<=15)&(y>-5&y<5)],pch=19,col="blue")
points(x[(x<5|x>15)&(y>-5&y<5)],y[(x<5|x>15)&(y>-5&y<5)])
# Out:
# Plot with title “”

# %%
plot(x,y,type="n",main="") #type="n" creats an empty plot
abline(h=c(-5,5),col="red",lty=2,lwd=2) # add straight lines
# “from” coordinate (given as x0 and y0) and a “to” coordinate (as x1 and y1)
segments(x0=c(5,15),y0=c(-5,-5),x1=c(5,15),y1=c(5,5),col="red",lty=3,lwd=2) 
points(x[y>=5],y[y>=5],pch=4,col="darkmagenta",cex=2)
points(x[y<=-5],y[y<=-5],pch=4,col="darkgreen",cex=2)
points(x[(x>=5&x<=15)&(y>-5&y<5)],y[(x>=5&x<=15)&(y>-5&y<5)],pch=19,col="blue")
points(x[(x<5|x>15)&(y>-5&y<5)],y[(x<5|x>15)&(y>-5&y<5)])
lines(x,y,lty=4)
# Out:
# Plot with title ""

# %%
plot(x,y,type="n",main="") #type="n" creats an empty plot
abline(h=c(-5,5),col="red",lty=2,lwd=2) # add straight lines
# “from” coordinate (given as x0 and y0) and a “to” coordinate (as x1 and y1)
segments(x0=c(5,15),y0=c(-5,-5),x1=c(5,15),y1=c(5,5),col="red",lty=3,lwd=2) 
points(x[y>=5],y[y>=5],pch=4,col="darkmagenta",cex=2)
points(x[y<=-5],y[y<=-5],pch=4,col="darkgreen",cex=2)
points(x[(x>=5&x<=15)&(y>-5&y<5)],y[(x>=5&x<=15)&(y>-5&y<5)],pch=19,col="blue")
points(x[(x<5|x>15)&(y>-5&y<5)],y[(x<5|x>15)&(y>-5&y<5)])
lines(x,y,lty=4)
arrows(x0=8,y0=14,x1=11,y1=2.5)
text(x=8,y=15,labels="sweet spot")
# Out:
# Plot with title “”

# %%
plot(x,y,type="n",main="") #type="n" creats an empty plot
abline(h=c(-5,5),col="red",lty=2,lwd=2) # add straight lines
# “from” coordinate (given as x0 and y0) and a “to” coordinate (as x1 and y1)
segments(x0=c(5,15),y0=c(-5,-5),x1=c(5,15),y1=c(5,5),col="red",lty=3,lwd=2) 
points(x[y>=5],y[y>=5],pch=4,col="darkmagenta",cex=2)
points(x[y<=-5],y[y<=-5],pch=4,col="darkgreen",cex=2)
points(x[(x>=5&x<=15)&(y>-5&y<5)],y[(x>=5&x<=15)&(y>-5&y<5)],pch=19,col="blue")
points(x[(x<5|x>15)&(y>-5&y<5)],y[(x<5|x>15)&(y>-5&y<5)])
lines(x,y,lty=4)
arrows(x0=8,y0=14,x1=11,y1=2.5)
text(x=8,y=15,labels="sweet spot")
legend("bottomleft",              #"topleft", "topright", "bottomleft", or "bottomright".
legend=c("overall process","sweet","standard",
"too big","too small","sweet y range","sweet x range"),
pch=c(NA,19,1,4,4,NA,NA),lty=c(4,NA,NA,NA,NA,2,3),
col=c("black","blue","black","darkmagenta","darkgreen","red","red"),
lwd=c(1,NA,NA,NA,NA,2,2),pt.cex=c(NA,1,1,2,2,NA,NA))
# Out:
# Plot with title ""

# %% [markdown]
# #### The ggplot2 Package

# %%
library("ggplot2")  #grammar of graphics

# %%
options(repr.plot.width=6, repr.plot.height=6)
foo <- c(1.1,2,3.5,3.9,4.2)
bar <- c(2,2.2,-1.3,0,0.2)
qplot(foo,bar)
# Out:
# plot without title

# %%
qplot(foo,bar,main="                     My lovely qplot",xlab="x axis label",ylab="location y")
# Out:
# plot without title

# %%
baz <- plot(foo,bar)
baz
# Out:
# NULL
# plot without title

# %%
qux <- qplot(foo,bar)
qux   #unlike plot, qux is an object.
# Out:
# plot without title

# %%
qplot(foo,bar,geom="blank") + geom_point() + geom_line() #geometric modifiers (geoms)
# Out:
# plot without title

# %%
qplot(foo,bar,geom="blank") + 
          geom_point(size=3,shape=6,color="blue") +    #setting cex=3 and pch=6
          geom_line(color="red",linetype=2)
# Out:
# plot without title

# %%
myqplot <- qplot(foo,bar,geom="blank") + geom_line(color="red",linetype=2)
myqplot + geom_point(size=3,shape=3,color="blue")
myqplot + geom_point(size=3,shape=7,color="blue")
# Out:
# plot without title
# plot without title

# %%
x <- 1:20
y <- c(-1.49,3.37,2.59,-2.78,-3.94,-0.92,6.43,8.51,3.41,-8.23,
-12.01,-6.58,2.87,14.12,9.63,-4.58,-14.78,-11.67,1.17,15.62)

# %%
ptype <- rep(NA,length(x=x))
ptype[y>=5] <- "too_big"
ptype[y<=-5] <- "too_small"
ptype[(x>=5&x<=15)&(y>-5&y<5)] <- "sweet"
ptype[(x<5|x>15)&(y>-5&y<5)] <- "standard"
ptype <- factor(x=ptype)
print(ptype)
# Out:
#  [1] standard  standard  standard  standard  sweet     sweet     too_big
#  [8] too_big   sweet     too_small too_small too_small sweet     too_big
# [15] too_big   standard  too_small too_small standard  too_big
# Levels: standard sweet too_big too_small

# %%
options(repr.plot.width=6, repr.plot.height=4)
qplot(x,y,color=ptype,shape=ptype)
# Out:
# plot without title

# %%
qplot(x,y,color=ptype,shape=ptype) + geom_point(size=4) +
geom_line(mapping=aes(group=1),color="black",lty=2) +        #treat all the observations as one group 
geom_hline(mapping=aes(yintercept=c(-5,5)),color="red") +
geom_segment(mapping=aes(x=5,y=-5,xend=5,yend=5),color="red",lty=3) +
geom_segment(mapping=aes(x=15,y=-5,xend=15,yend=5),color="red",lty=3)
# Out:
# plot without title

# %%
attach(mtcars)
options(repr.plot.width=8, repr.plot.height=8)
print(mtcars)
# Out:
# The following object is masked from package:ggplot2:
#
#     mpg
#                      mpg cyl  disp  hp drat    wt  qsec vs am gear carb
# Mazda RX4           21.0   6 160.0 110 3.90 2.620 16.46  0  1    4    4
# Mazda RX4 Wag       21.0   6 160.0 110 3.90 2.875 17.02  0  1    4    4
# Datsun 710          22.8   4 108.0  93 3.85 2.320 18.61  1  1    4    1
# Hornet 4 Drive      21.4   6 258.0 110 3.08 3.215 19.44  1  0    3    1
# Hornet Sportabout   18.7   8 360.0 175 3.15 3.440 17.02  0  0    3    2
# Valiant             18.1   6 225.0 105 2.76 3.460 20.22  1  0    3    1
# Duster 360          14.3   8 360.0 245 3.21 3.570 15.84  0  0    3    4
# Merc 240D           24.4   4 146.7  62 3.69 3.190 20.00  1  0    4    2
# Merc 230            22.8   4 140.8  95 3.92 3.150 22.90  1  0    4    2
# Merc 280            19.2   6 167.6 123 3.92 3.440 18.30  1  0    4    4
# Merc 280C           17.8   6 167.6 123 3.92 3.440 18.90  1  0    4    4
# ...

# %%
plot(wt, mpg)
abline(lm(mpg~wt))
title("Regression of MPG on Weight")
# Out:
# Plot with title “Regression of MPG on Weight”

# %%
dose  <- c(20, 30, 40, 45, 60)
drugA <- c(16, 20, 27, 40, 60)
drugB <- c(15, 18, 25, 31, 40)
plot(dose, drugA, type="b")
# Out:
# plot without title

# %%
opar <- par(no.readonly=TRUE) # make a copy of current settings
print(opar)
par(lty=2, pch=17)   #using par to change parameters
plot(dose, drugA, type="b")
par(opar)
# Out:
# $xlog
# [1] FALSE
#
# $ylog
# [1] FALSE
#
# $adj
# [1] 0.5
#
# $ann
# [1] TRUE
#
# $ask
# [1] FALSE
#
# $bg
# [1] "transparent"
#
# $bty
# [1] "o"
#
# $cex
# [1] 1
#
# $cex.axis
# [1] 1
#
# $cex.lab
# [1] 1
#
# $cex.main
# [1] 1.2
#
# $cex.sub
# [1] 1
#
# $col
# [1] "black"
#
# $col.axis
# [1] "black"
#
# $col.lab
# [1] "black"
#
# $col.main
# [1] "black"
#
# $col.sub
# [1] "black"
#
# $crt
# [1] 0
#
# $err
# [1] 0
#
# $family
# [1] ""
#
# $fg
# [1] "black"
#
# $fig
# [1] 0 1 0 1
#
# $fin
# [1] 7 7
#
# $font
# [1] 1
#
# $font.axis
# [1] 1
#
# $font.lab
# [1] 1
#
# $font.main
# [1] 2
#
# $font.sub
# [1] 1
#
# $lab
# [1] 5 5 7
#
# $las
# [1] 0
#
# $lend
# [1] "round"
#
# $lheight
# [1] 1
#
# $ljoin
# [1] "round"
#
# $lmitre
# [1] 10
#
# $lty
# [1] "solid"
#
# $lwd
# [1] 1
#
# $mai
# [1] 1.02 0.82 0.82 0.42
#
# $mar
# [1] 5.1 4.1 4.1 2.1
#
# $mex
# [1] 1
#
# $mfcol
# [1] 1 1
#
# $mfg
# [1] 1 1 1 1
#
# $mfrow
# [1] 1 1
#
# $mgp
# [1] 3 1 0
#
# $mkh
# [1] 0.001
#
# $new
# [1] FALSE
#
# ...

# %%
plot(dose, drugA, type="b", lty=3, lwd=3, pch=15, cex=2)
# Out:
# plot without title

# %%
library(RColorBrewer)

# %%
n <- 7
mycolors <- brewer.pal(n, "Set1")
mycolors
barplot(rep(1,n), col=mycolors)
# Out:
# [1] "#E41A1C" "#377EB8" "#4DAF4A" "#984EA3" "#FF7F00" "#FFFF33" "#A65628"
# plot without title

# %%
n <- 10
mycolors <- rainbow(n)
mycolors
pie(rep(1, n), labels=mycolors, col=mycolors)  #饼图
mygrays <- gray(0:n/n)
mygrays
pie(rep(1, n), labels=mygrays, col=mygrays)
# Out:
#  [1] "#FF0000" "#FF9900" "#CCFF00" "#33FF00" "#00FF66" "#00FFFF" "#0066FF"
#  [8] "#3300FF" "#CC00FF" "#FF0099"
#  [1] "#000000" "#1A1A1A" "#333333" "#4D4D4D" "#666666" "#808080" "#999999"
#  [8] "#B3B3B3" "#CCCCCC" "#E6E6E6" "#FFFFFF"
# plot without title
# plot without title

# %%
options(repr.plot.width=8, repr.plot.height=8)
opar <- par(no.readonly=TRUE)
par(pin=c(2, 3))     #graph size
par(lwd=2, cex=1.5)
par(cex.axis=.75, font.axis=2)
plot(dose, drugA, type="b", pch=19, lty=2, col="red")
plot(dose, drugB, type="b", pch=23, lty=6, col="blue", bg="green")
par(opar)
# Out:
# plot without title
# plot without title

# %%
options(repr.plot.width=4, repr.plot.height=4)
plot(dose, drugA, type="b",  
     col="red", lty=2, pch=2, lwd=2,
     main="Clinical Trials for Drug A", 
     sub="This is hypothetical data", 
     xlab="Dosage", ylab="Drug Response",
     xlim=c(0, 60), ylim=c(0, 70))
# Out:
# Plot with title “Clinical Trials for Drug A”

# %%
options(repr.plot.width=6, repr.plot.height=5)
x <- c(1:10)
y <- x
z <- 10/x
opar <- par(no.readonly=TRUE)
par(mar=c(5, 4, 4, 8) + 0.1)   #define the margin:bottom, left, top and right
plot(x, y, type="b",
     pch=21, col="red",
     yaxt="n", lty=3, ann=FALSE)   #ann indicating whether the default annotation (title and x and y axis labels) should appear on the plot
# yaxt indicating whether y axis is plotted.
lines(x, z, type="b", pch=22, col="blue", lty=2)
axis(2, at=x, labels=x, col.axis="red", las=2)   #1=below, 2=left, 3=above and 4=right, las indicating labels are parallel (=0) or perpendicular(=2) to axis
axis(4, at=z, labels=round(z, digits=2),
     col.axis="blue", las=2, cex.axis=0.7, tck=-.01)   #tck for tick mark length and direction
mtext("y=1/x", side=4, line=3, cex.lab=1, las=2, col="blue") #Text is written in one of the four margins
title("An Example of Creative Axes",
      xlab="X values",
      ylab="Y=X")
par(opar)
# Out:
# Plot with title "An Example of Creative Axes"

# %%
options(repr.plot.width=6, repr.plot.height=6)
opar <- par(no.readonly=TRUE)
par(mfrow=c(2,2))    #2 rows and 2 cols
plot(wt,mpg, main="Scatterplot of wt vs. mpg")
plot(wt,disp, main="Scatterplot of wt vs. disp")
hist(wt, main="Histogram of wt")
boxplot(wt, main="Boxplot of wt")
par(opar)
# Out:
# Plot with title “Boxplot of wt”

# %%
options(repr.plot.width=4, repr.plot.height=12)
opar <- par(no.readonly=TRUE)
par(mfrow=c(3,1))
hist(wt)
hist(mpg)
hist(disp)
par(opar)
# Out:
# Plot with title “Histogram of disp”

# %% [markdown]
# #### ggplot2 examples

# %%
library(ggplot2)
df <- data.frame(
  x = c(1, 2), y = c(2, 1), tmp=c(1,2)
)

ggplot(df, aes(x, y + 1)) +
  geom_point(colour = "green") +
  geom_line(colour = "blue")
# Out:
# plot without title

# %%
ggplot(df, aes(x, y + 1)) +
  geom_point(colour = "green") +
  geom_line(aes(colour = "blue"))
# Out:
# plot without title

# %%
library(ggplot2)

df1 <- data.frame(
  x = rep(1:3, 2),
  y = c(1, 2, 3, 3, 2, 1),
  group = c("A", "A", "A", "B", "B", "B")
)

ggplot(df1, aes(x, y, colour = group)) +
  geom_line()
# Out:
# plot without title

# %%
ggplot(df, aes(x, y + 1)) +
  geom_point(colour = "green") +
  geom_line(aes(colour = tmp))
# Out:
# plot without title

# %%
ggplot(df, aes(x, y + 1)) +
  geom_point(aes(colour = tmp)) +
  geom_line(colour="magenta")
# Out:
# plot without title

# %%
options(repr.plot.width=8, repr.plot.height=8)
#aes stands for aesthetics, or how information is represented visually
ggplot(data=mtcars, aes(x=wt, y=mpg)) +          #using ggplot instead of qplot
  geom_point() +
  labs(title="                 Automobile Data", x="Weight", y="Miles Per Gallon")
# Out:
# plot without title

# %%
# Scatter plot with additional options
ggplot(data=mtcars, aes(x=wt, y=mpg)) +
  geom_point(pch=17, color="blue", size=2) +
  geom_smooth(method="lm", color="red", linetype=2) +
  labs(title="                    Automobile Data", x="Weight", y="Miles Per Gallon")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
#grouping and faceting
options(repr.plot.width=6, repr.plot.height=6)
mtcars$am <- factor(mtcars$am, levels=c(0,1),
                    labels=c("Automatic", "Manual"))
mtcars$vs <- factor(mtcars$vs, levels=c(0,1),
                    labels=c("V-Engine", "Straight Engine"))
mtcars$cyl <- factor(mtcars$cyl)
ggplot(data=mtcars, aes(x=hp, y=mpg, shape=cyl, color=cyl)) +         #hp = horsepower, mpg =  miles per gallon
  geom_point(size=3) +
  facet_grid(am~vs) +
  labs(title="Automobile Data by Engine Type", x="Horsepower", y="Miles Per Gallon")
# Out:
# plot without title

# %% [markdown]
# #### Specifying the plot type with geoms
# ![image.png](attachment:61a1dd7f-2e5e-4103-acfc-8b89be0c5c7c.png)

# %%
install.packages("carData")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
# Making 'packages.html' ...
#  done

# %%
data(Salaries, package="carData")
head(Salaries)
# Out:
#   rank      discipline yrs.since.phd yrs.service sex  salary
# 1 Prof      B          19            18          Male 139750
# 2 Prof      B          20            16          Male 173200
# 3 AsstProf  B           4             3          Male  79750
# 4 Prof      B          45            39          Male 115000
# 5 Prof      B          40            41          Male 141500
# 6 AssocProf B           6             6          Male  97000

# %%
options(repr.plot.width=8, repr.plot.height=8)
ggplot(Salaries, aes(x=salary)) + geom_histogram(bins=10)
# Out:
# plot without title

# %%
ggplot(Salaries, aes(x=rank, y=salary)) + geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# #### Common options for geom functions
# ![image.png](attachment:cb8a5058-c786-45fb-8bc6-6283b3cc7a6d.png)

# %%
ggplot(Salaries, aes(x=rank, y=salary)) +
  geom_boxplot(fill="cornflowerblue",
               color="black", notch=TRUE)+
  geom_point(position="jitter", color="blue", alpha=.5)+
  geom_rug(color="black")
# Out:
# plot without title

# %%
data(singer, package="lattice")
head(singer)
# Out:
#   height voice.part
# 1 64     Soprano 1
# 2 62     Soprano 1
# 3 66     Soprano 1
# 4 65     Soprano 1
# 5 60     Soprano 1
# 6 61     Soprano 1

# %%
options(repr.plot.width=8, repr.plot.height=8)
pdf("test.pdf",width=8,height=10)
ggplot(singer, aes(x=voice.part, y=height)) +
           geom_violin(fill="lightblue") +
           geom_boxplot(fill="lightgreen", width=.2)   #combine violinplot and boxplot together
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# #### Grouping

# %%
options(repr.plot.width=6, repr.plot.height=4)
ggplot(data=Salaries, aes(x=salary, fill=rank)) +             #filled by rank
                geom_density(alpha=.3)
# Out:
# plot without title

# %%
ggplot(data=Salaries, aes(x=salary,fill='red')) +     
                geom_density(alpha=.3)
# Out:
# plot without title

# %%
ggplot(Salaries, aes(x=yrs.since.phd, y=salary, color=rank,shape=sex)) + geom_point()
# Out:
# plot without title

# %%
options(repr.plot.width=4, repr.plot.height=2)
ggplot(Salaries, aes(x=rank, fill=sex)) +
         geom_bar(position="stack") + labs(title='position="stack"')
ggplot(Salaries, aes(x=rank, fill=sex)) +
         geom_bar(position="dodge") + labs(title='position="dodge"')
ggplot(Salaries, aes(x=rank, fill=sex)) +
         geom_bar(position="fill") + labs(title='position="fill"')
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# #### Faceting

# %% [markdown]
# ![image.png](attachment:1e1577ea-e3e3-4336-8114-8afde7bcd04d.png)
# ![image.png](attachment:b4b2fa97-744c-4e81-8884-ada7f8826fe8.png)

# %%
options(repr.plot.width=6, repr.plot.height=6)
ggplot(data=singer, aes(x=height)) +
                  geom_histogram(bins=10) +
                  facet_wrap(~voice.part, nrow=4)
# Out:
# plot without title

# %%
options(repr.plot.width=6, repr.plot.height=3)
ggplot(Salaries, aes(x=yrs.since.phd, y=salary, color=rank,shape=rank)) + 
             geom_point() + facet_grid(.~sex)
# Out:
# plot without title

# %%
options(repr.plot.width=4, repr.plot.height=6)
ggplot(data=singer, aes(x=height, fill=voice.part)) +
        geom_density() +
        facet_grid(voice.part~.)
# Out:
# plot without title

# %% [markdown]
# #### Modifying the appearance of ggplot2 graphs

# %%
options(repr.plot.width=4, repr.plot.height=4)
ggplot(data=Salaries, aes(x=rank, y=salary, fill=sex)) +
             geom_boxplot() + 
            labs(title="Faculty Salary by Rank and Gender",x="", y="", fill="Gender") +
             theme(legend.position=c(.2,.8))             #legend position
# Out:
# plot without title

# %%
options(repr.plot.width=6, repr.plot.height=4)
ggplot(mtcars, aes(x=wt, y=mpg, size=disp)) +
             geom_point(shape=21, color="black", fill="cornsilk") +
             labs(x="Weight", y="Miles Per Gallon",title="Bubble Chart", size="Engine\nDisplacement")
# Out:
# plot without title

# %%
mytheme <- theme(plot.title=element_text(face="bold.italic", size="14", color="brown"),
axis.title=element_text(face="bold.italic", size=10, color="brown"),
axis.text=element_text(face="bold", size=9, color="darkblue"),
panel.background=element_rect(fill="white", color="darkblue"),
panel.grid.major.y=element_line(color="grey", linetype=1),
panel.grid.minor.y=element_line(color="grey", linetype=2),
panel.grid.minor.x=element_blank(), legend.position="top")
ggplot(Salaries, aes(x=rank, y=salary, fill=sex)) +
geom_boxplot() +
labs(title="Salary by Rank and Sex", x="Rank", y="Salary") +
mytheme
# Out:
# plot without title

# %% [markdown]
# #### saving graph

# %%
ggplot(data=mtcars, aes(x=mpg)) + geom_histogram(bins = 30)
ggsave(file="mygraph.pdf")
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %% [markdown]
# #### READING AND WRITING FILES

# %% [markdown]
# ##### Built-in Data Sets

# %%
library(help="datasets")
# Out:
# Documentation for package 'datasets'
#
#
# 		Information on package 'datasets'
#
# Description:
#
# Package:       datasets
# Version:       3.6.1
# Priority:      base
# Title:         The R Datasets Package
# Author:        R Core Team and contributors worldwide
# Maintainer:    R Core Team <R-core@r-project.org>
# Description:   Base R datasets.
# License:       Part of R 3.6.1
# Built:         R 3.6.1; ; 2019-08-06 20:41:16 UTC; windows
#
# Index:
#
# AirPassengers           Monthly Airline Passenger Numbers 1949-1960
# BJsales                 Sales Data with Leading Indicator
# BOD                     Biochemical Oxygen Demand
# CO2                     Carbon Dioxide Uptake in Grass Plants
# ChickWeight             Weight versus age of chicks on different diets
# DNase                   Elisa assay of DNase
# EuStockMarkets          Daily Closing Prices of Major European Stock
#                         Indices, 1991-1998
# Formaldehyde            Determination of Formaldehyde
# ...

# %%
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %% [markdown]
# ##### Contributed Data Sets

# %%
data(Salaries, package="carData")

# %%
head(Salaries)
# Out:
#   rank      discipline yrs.since.phd yrs.service sex  salary
# 1 Prof      B          19            18          Male 139750
# 2 Prof      B          20            16          Male 173200
# 3 AsstProf  B           4             3          Male  79750
# 4 Prof      B          45            39          Male 115000
# 5 Prof      B          40            41          Male 141500
# 6 AssocProf B           6             6          Male  97000

# %% [markdown]
# ##### Reading in External Data Files

# %%
mydatafile <- read.table(file="mydatafile.txt",header=TRUE,sep=" ",na.strings="*",stringsAsFactors=FALSE)

# %%
head(mydatafile)
# Out:
#   person age sex funny age.mon
# 1 Peter  NA  M   High  504
# 2 Lois   40  F   NA    480
# 3 Meg    17  F   Low   204
# 4 Chris  14  M   Med   168
# 5 Stewie  1  M   High   NA
# 6 Brian  NA  M   Med    NA

# %%
head(list.files("."))
# Out:
# [1] "alldisnet.results" "allesp.results"    "alliupred.results"
# [4] "allproteins.label" "allspot.results"   "AUC_box.pdf"

# %%
file.choose()
# Out:
# Error in file.choose(): 撤消文件选择
# Traceback:
#
# 1. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = invokeRestart("eval_error",
#  .             cnd))
#  . }, "撤消文件选择", base::quote(file.choose()))

# %%
mydatafile <- read.table(file=file.choose(),header=TRUE,sep=" ",na.strings="*",stringsAsFactors=FALSE)

# %%
head(mydatafile)
# Out:
#   person age sex funny age.mon
# 1 Peter  NA  M   High  504
# 2 Lois   40  F   NA    480
# 3 Meg    17  F   Low   204
# 4 Chris  14  M   Med   168
# 5 Stewie  1  M   High   NA
# 6 Brian  NA  M   Med    NA

# %%
#convert xlsx to csv
spread <- read.csv(file="spreadsheetfile.csv",header=FALSE,stringsAsFactors=TRUE)

# %%
head(spread)
# Out:
#   V1 V2  V3
# 1 55 161 female
# 2 85 185 male
# 3 75 174 male
# 4 42 154 female
# 5 93 188 male
# 6 63 178 male

# %%
write.table(x=mydatafile,file="somenewfile.txt",sep="@",na="??",quote=FALSE,row.names=FALSE)

# %%
head(Salaries)
# Out:
#   rank      discipline yrs.since.phd yrs.service sex  salary
# 1 Prof      B          19            18          Male 139750
# 2 Prof      B          20            16          Male 173200
# 3 AsstProf  B           4             3          Male  79750
# 4 Prof      B          45            39          Male 115000
# 5 Prof      B          40            41          Male 141500
# 6 AssocProf B           6             6          Male  97000

# %%
saveRDS(file="s.rds",Salaries)

# %%
tests=readRDS("s.rds")

# %%
head(tests)
